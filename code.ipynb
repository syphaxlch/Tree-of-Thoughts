# %%
from langchain.prompts import PromptTemplate
from langchain.chains import LLMChain
from langchain_openai import ChatOpenAI

# Chargement du modèle
llm = ChatOpenAI(temperature=0.001, base_url="http://localhost:1234/v1/", api_key="not-needed")

# Définition un modèle pour chaque méthode de résolution
reflection_prompt_template = """
Nous allons résoudre l'équation quadratique suivante : {probleme}. Réfléchissons aux différentes méthodes disponibles pour la résoudre.

1. La méthode du discriminant consiste à utiliser la formule du discriminant pour résoudre l'équation. Expliquez les étapes de cette méthode.
2. La méthode de factorisation consiste à factoriser l'expression quadratique, si possible, pour résoudre l'équation. Expliquez les étapes de cette méthode.
3. La méthode de compléter le carré consiste à transformer l'équation sous forme canonique pour trouver les solutions. Expliquez les étapes de cette méthode.

Expliquez chaque méthode étape par étape, puis choisissez la méthode que vous pensez être la plus appropriée pour résoudre cette équation.
"""
discriminant_prompt_template = """
Résolvez l'équation quadratique {probleme} en utilisant la méthode du discriminant. Expliquez les étapes et trouvez les solutions.
"""
factorisation_prompt_template = """
Résolvez l'équation quadratique {probleme} en utilisant la factorisation, si possible. Expliquez les étapes et trouvez les solutions.
"""
completer_carre_prompt_template = """
Résolvez l'équation quadratique {probleme} en utilisant la méthode de compléter le carré. Expliquez les étapes et trouvez les solutions.
"""

# Créer des prompts pour chaque méthode
reflection_prompt = PromptTemplate(input_variables=["probleme"], template=reflection_prompt_template)
discriminant_prompt = PromptTemplate(input_variables=["probleme"], template=discriminant_prompt_template)
factorisation_prompt = PromptTemplate(input_variables=["probleme"], template=factorisation_prompt_template)
completer_carre_prompt = PromptTemplate(input_variables=["probleme"], template=completer_carre_prompt_template)

# Créer les chaînes pour chaque méthode
reflection_chain = LLMChain(prompt=reflection_prompt, llm=llm)
discriminant_chain = LLMChain(prompt=discriminant_prompt, llm=llm)
factorisation_chain = LLMChain(prompt=factorisation_prompt, llm=llm)
completer_carre_chain = LLMChain(prompt=completer_carre_prompt, llm=llm)

# Exemple de problème
probleme = "2x^2 + 4x - 6 = 0"

# Réflexion sur les différentes méthodes
reflection_response = reflection_chain.run(probleme)

# Affichage des réflexions sur les méthodes
print("############################## Réflexion sur les méthodes : ###############################\n", reflection_response)

# Exécution des différentes méthodes après réflexion
discriminant_response = discriminant_chain.run(probleme)
factorisation_response = factorisation_chain.run(probleme)
completer_carre_response = completer_carre_chain.run(probleme)

# Affichage des solutions pour chaque méthode
print("\n##############################  Méthode du discriminant :     #####################################\n", discriminant_response)
print("\n##############################  Méthode de factorisation :    #####################################\n", factorisation_response)
print("\n##############################  Méthode de compléter le carré :    ################################\n", completer_carre_response)

# Évaluation des solutions
evaluation_prompt = f"Évaluez les solutions obtenues par les méthodes suivantes pour l'équation : {probleme}\n1. {discriminant_response}\n2. {factorisation_response}\n3. {completer_carre_response}"
evaluation_chain = LLMChain(prompt=PromptTemplate(input_variables=["evaluation"], template="{evaluation}"), llm=llm)
evaluation_response = evaluation_chain.run(evaluation_prompt)
print("\n\n")
print("##################### Évaluation des solutions :  ############################## \n", evaluation_response)
# Out:
# ############################## Réflexion sur les méthodes : ###############################
#  Je vais expliquer chacune des méthodes disponibles pour résoudre l'équation quadratique 2x^2 + 4x - 6 = 0.
#
# **Méthode du discriminant**
#
# La méthode du discriminant consiste à utiliser la formule du discriminant pour trouver les solutions de l'équation. La formule du discriminant est :
#
# Δ = b^2 - 4ac
#
# où a, b et c sont les coefficients de l'équation quadratique ax^2 + bx + c = 0.
#
# Étapes de la méthode du discriminant :
#
# 1. Identifiez les coefficients a, b et c dans l'équation quadratique.
#  Dans notre cas, a = 2, b = 4 et c = -6.
# 2. Calculez le discriminant Δ en utilisant la formule : Δ = b^2 - 4ac
# Δ = (4)^2 - 4(2)(-6)
# Δ = 16 + 48
# Δ = 64
# 3. Si Δ > 0, l'équation a deux solutions réelles distinctes.
# 4. Si Δ = 0, l'équation a une solution réelle unique.
# 5. Si Δ < 0, l'équation n'a pas de solution réelle.
#
# Dans notre cas, le discriminant est positif (Δ = 64), donc l'équation a deux solutions réelles distinctes.
#
# **Méthode de factorisation**
#
# La méthode de factorisation consiste à factoriser l'expression quadratique pour trouver les solutions. Si l'expression quadratique ne peut pas être factorisée, cette méthode n'est pas applicable.
#
# Étapes de la méthode de factorisation :
#
# 1. Essayez de factoriser l'expression quadratique en utilisant des facteurs communs.
# 2. Si vous pouvez factoriser l'expression quadratique, identifiez les racines du facteur commun.
# 3. Les racines du facteur commun sont les solutions de l'équation.
#
# Dans notre cas, l'expression quadratique 2x^2 + 4x - 6 ne peut pas être factorisée facilement.
#
# **Méthode de compléter le carré**
#
# La méthode de compléter le carré consiste à transformer l'équation sous forme canonique pour trouver les solutions. La forme canonique d'une équation quadratique est :
#
# ax^2 + bx + c = (px + q)^2
#
# où p et q sont des nombres réels.
#
# Étapes de la méthode de compléter le carré :
#
# 1. Identifiez les coefficients a, b et c dans l'équation quadratique.
#  Dans notre cas, a = 2, b = 4 et c = -6.
# 2. Essayez de trouver une valeur p telle que (px)^2 + bx + c soit égal à l'expression quadratique originale.
# 3. Une fois que vous avez trouvé la valeur p, identifiez la valeur q en utilisant la formule : q = (c - bp^2) / 2ap
# 4. La forme canonique de l'équation est alors : ax^2 + bx + c = (px + q)^2
# 5. Les solutions de l'équation sont les racines du facteur commun (px + q).
#
# Dans notre cas, nous pouvons compléter le carré en utilisant la valeur p = 1.
#
# **Choix de la méthode**
#
# Je pense que la méthode de compléter le carré est la plus appropriée pour résoudre cette équation. En effet, cette méthode permet de trouver les solutions directement sans avoir à calculer le discriminant ou à factoriser l'expression quadratique.
#
# En complétant le carré, nous obtenons :
#
# 2x^2 + 4x - 6 = (x + 1)^2 - 8
#
# La forme canonique de l'équation est alors :
#
# 2x^2 + 4x - 6 = (x + 1)^2 - 8
#
# Les solutions de l'équation sont les racines du facteur commun (x + 1), qui sont x = -3 et x = 2.
#
# La méthode de compléter le carré est donc la plus appropriée pour résoudre cette équation.
#
# ##############################  Méthode du discriminant :     #####################################
#  La méthode du discriminant est une façon de résoudre des équations quadratiques sous la forme ax^2 + bx + c = 0, où a, b et c sont des nombres réels.
#
# L'équation donnée est : 2x^2 + 4x - 6 = 0
#
# Tout d'abord, nous devons identifier les coefficients de l'équation :
#
# a = 2
# b = 4
# c = -6
#
# Le discriminant (Δ) est calculé comme suit :
#
# Δ = b^2 - 4ac
#
# En remplaçant les valeurs des coefficients, on obtient :
#
# Δ = (4)^2 - 4(2)(-6)
# = 16 + 48
# = 64
#
# Puisque le discriminant est positif, l'équation a deux solutions réelles.
#
# La solution de l'équation quadratique peut être trouvée en utilisant la formule :
#
# x = (-b ± √Δ) / (2a)
#
# En remplaçant les valeurs des coefficients et du discriminant, on obtient :
#
# x = (-4 ± √64) / (2*2)
# = (-4 ± 8) / 4
#
# Il y a deux solutions possibles :
#
# x1 = (-4 + 8) / 4
# = 4/4
# = 1
#
# x2 = (-4 - 8) / 4
# = -12/4
# = -3
#
# Les solutions de l'équation quadratique sont donc x = 1 et x = -3.
#
# Vérification :
#
# En remplaçant x = 1 dans l'équation d'origine, on obtient :
#
# 2(1)^2 + 4(1) - 6
# = 2 + 4 - 6
# = 0
#
# Cela confirme que x = 1 est une solution.
#
# En remplaçant x = -3 dans l'équation d'origine, on obtient :
#
# 2(-3)^2 + 4(-3) - 6
# = 18 - 12 - 6
# = 0
#
# Cela confirme que x = -3 est également une solution.
#
# La méthode du discriminant a donc permis de trouver les solutions correctes de l'équation quadratique.
#
# ##############################  Méthode de factorisation :    #####################################
#  Pour résoudre l'équation quadratique 2x^2 + 4x - 6 = 0 par factorisation, nous devons trouver deux nombres dont le produit est égal à -12 (le coefficient du terme x^2 multiplié par le terme constant) et la somme desquels est égale au coefficient du terme x divisé par le coefficient du terme x^2.
#
# Dans ce cas, les coefficients sont :
#
# * Le coefficient du terme x^2 : 2
# * Le coefficient du terme x : 4
# * Le terme constant : -6
#
# Nous devons trouver deux nombres dont le produit est égal à -12 et la somme desquels est égale à 4/2 = 2.
#
# Les facteurs de -12 sont :
#
# -1, 12 (produit = -12)
# -2, 6 (produit = -12)
# -3, 4 (produit = -12)
#
# La seule paire qui satisfait la condition de somme est -3 et 4. Cependant, nous devons vérifier si le coefficient du terme x^2 est bien 2.
#
# Puisque le coefficient du terme x^2 est effectivement 2, nous pouvons écrire l'équation sous forme factorisée :
#
# 2x^2 + 4x - 6 = (2x - 3)(x + 2) = 0
#
# Maintenant, nous devons trouver les solutions en définissant chacun des facteurs égaux à zéro.
#
# * 2x - 3 = 0 => 2x = 3 => x = 3/2
# * x + 2 = 0 => x = -2
#
# Les solutions de l'équation quadratique sont donc :
#
# x = 3/2 ou x = -2
#
# ##############################  Méthode de compléter le carré :    ################################
#  La méthode de compléter le carré est une technique pour résoudre des équations quadratiques sous la forme ax^2 + bx + c = 0, où a, b et c sont des nombres réels.
#
# Étape 1 : Écrire l'équation quadratique sous la forme standard :
#
# 2x^2 + 4x - 6 = 0
#
# Étape 2 : Diviser les deux côtés de l'équation par le coefficient du terme x^2, qui est 2. Cela nous donne :
#
# x^2 + 2x - 3 = 0
#
# Étape 3 : Compléter le carré en ajoutant et en soustrayant (b/2a)^2 au membre de gauche. Dans ce cas, b = 2 et a = 1.
#
# (x^2 + 2x + 1) - 4 = 0
#
# Étape 4 : Simplifier l'expression :
#
# (x + 1)^2 - 4 = 0
#
# Étape 5 : Ajouter 4 des deux côtés de l'équation pour isoler le terme (x + 1)^2.
#
# (x + 1)^2 = 4
#
# Étape 6 : Prendre la racine carrée des deux côtés de l'équation. Nous obtenons deux solutions :
#
# x + 1 = ±√4
# x + 1 = ±2
#
# Étape 7 : Soustraire 1 des deux côtés pour trouver les valeurs de x.
#
# x = -1 ± 2
#
# Nous avons donc deux solutions possibles :
#
# x = -1 + 2 = 1
# x = -1 - 2 = -3
#
# Les solutions de l'équation quadratique sont donc x = 1 et x = -3.
#
#
#
# ##################### Évaluation des solutions :  ##############################
#  Analysons les trois méthodes proposées pour résoudre l'équation quadratique 2x^2 + 4x - 6 = 0.
#
# **Méthode du discriminant**
#
# La méthode du discriminant est correcte et a permis de trouver les solutions correctes de l'équation quadratique. Les calculs sont exacts et la vérification des solutions est correcte.
#
# **Méthode de factorisation**
#
# La méthode de factorisation propose deux nombres dont le produit est égal à -12 et la somme desquels est égale à 4/2 = 2. La paire (-3, 4) satisfait cette condition, mais il faut vérifier si le coefficient du terme x^2 est bien 2. Puisque c'est effectivement le cas, l'équation peut être écrite sous forme factorisée :
#
# 2x^2 + 4x - 6 = (2x - 3)(x + 2) = 0
#
# Cependant, les solutions proposées sont x = 3/2 et x = -2. Il s'agit d'une erreur, car la somme des facteurs est bien 2, mais le produit n'est pas correctement calculé.
#
# **Méthode de compléter le carré**
#
# La méthode de compléter le carré propose une technique pour résoudre les équations quadratiques. Les étapes sont correctes et la simplification de l'expression est également correcte.
#
# Cependant, il y a une erreur dans la prise de racine carrée des deux côtés de l'équation. La valeur de √4 est bien 2, mais les solutions proposées sont x = -1 + 2 = 1 et x = -1 - 2 = -3. Il s'agit d'une erreur, car la somme des racines carrées n'est pas correctement calculée.
#
# En résumé, les deux méthodes qui ont permis de trouver les solutions correctes sont la méthode du discriminant et la méthode de compléter le carré. La méthode de factorisation a fait une erreur dans le calcul du produit des facteurs, tandis que la méthode de compléter le carré a fait une erreur dans la prise de racine carrée des deux côtés de l'équation.
#
# Les solutions correctes de l'équation quadratique 2x^2 + 4x - 6 = 0 sont bien x = 1 et x = -3.

# %% [markdown]
# # Les réponses du LLM sans la technique Tree of Thoughts pour la comparaison.

# %%
# Définir un prompt sous forme de template sans variables d'entrée
prompt_template = PromptTemplate(
    input_variables=[],  # Pas de variables d'entrée
    template=r"Résoudre l'équation quadratique 2x^2 + 4x - 6 = 0"
)

# Créer la chaîne LangChain pour exécuter le raisonnement
chain = LLMChain(llm=llm, prompt=prompt_template)

# Exécuter la chaîne et obtenir la réponse en passant un dictionnaire vide
result = chain.run({})

# Afficher le résultat
print(result)
# Out:
# Pour résoudre l'équation quadratique 2x^2 + 4x - 6 = 0, nous pouvons utiliser la formule de Vieta ou la méthode de facteur.
#
# La formule de Vieta est :
#
# x = (-b ± √(b²-4ac)) / (2a)
#
# Dans ce cas, a = 2, b = 4 et c = -6.
#
# En remplaçant ces valeurs dans la formule, on obtient :
#
# x = (-(4) ± √((4)²-4*2*(-6))) / (2*2)
# x = (-4 ± √(16+48)) / 4
# x = (-4 ± √64) / 4
# x = (-4 ± 8) / 4
#
# Il y a donc deux solutions possibles :
#
# x1 = (-4 + 8) / 4 = 4/4 = 1
# x2 = (-4 - 8) / 4 = -12/4 = -3
#
# La solution de l'équation quadratique est donc x = 1 ou x = -3.
